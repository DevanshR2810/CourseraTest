# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Devansh Ranjan</b><br>
# Desired Occupation: Data Scientist

# %% [markdown]
# <i>I am interested in data science because it is a field that utilises my prefered programming language, Python. It is also a booming field in the IT industry, which is a bonus.</i>

# %% [markdown]
# The following code will print the statement, "Data Science is fun!".

# %%
print("Data Science is fun!")
# Out:
# Data Science is fun!

# %% [markdown]
# <ul>
#     <li>Dwight Schrute</li>
#     <li>Sansa Stark</li>
#     <li>Caroline Forbes</li>
#     <li>Ron Swanson</li>
#     <li>Number 5</li>
# </ul>
# <ol>
#     <li>Homelander</li>
#     <li>Niklaus Mikaelson</li>
#     <li>Omni-Man</li>
#     <li>Yennefer<li>
#     <li>Robin Buckley</li>
# </ol>
# <a href="https://www.youtube.com/" target="_blank">Youtube</a>
